# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#importing the dataet 
file_path="C:/Users/Lenovo/Desktop/Machine learning for Data scinence/black/train.csv"
df=pd.read_csv(file_path)

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 0       P00069042       0  NaN          10             A
# 1       P00248942       0  NaN          10             A
# 2       P00087842       0  NaN          10             A
# 3       P00085442       0  NaN          10             A
# 4       P00285442       1  NaN          16             C
# ...           ...     ...  ...         ...           ...
# 550063  P00372445       1  NaN          13             B
# 550064  P00375436       0  NaN           1             C
# 550065  P00375436       0  NaN          15             B
# 550066  P00375436       0  NaN           1             C
# 550067  P00371644       0  NaN           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.drop(['User_ID'],axis=1,inplace=True)

# %%
df
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 550063  P00372445      M  51-55          13             B
# 550064  P00375436      F  26-35           1             C
# 550065  P00375436      F  26-35          15             B
# 550066  P00375436      F    55+           1             C
# 550067  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df['Gender']=df['Gender'].map({'F':0,'M':1})

# %%
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# ...

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Age']=df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# ...

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                           550068
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
#fixing categorical city categori
city=pd.get_dummies(df['City_Category'],drop_first=True)

# %%
city
# Out:
#             B      C
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False   True
# ...       ...    ...
# 550063   True  False
# 550064  False   True
# 550065   True  False
# 550066  False   True
# 550067   True  False
#
# [550068 rows x 2 columns]

# %%
df=pd.concat([df,city],axis=1)

# %%
df.head(5)
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0  NaN          10             A
# 1  P00248942       0  NaN          10             A
# 2  P00087842       0  NaN          10             A
# 3  P00085442       0  NaN          10             A
# 4  P00285442       1  NaN          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase      B      C
# 0                 NaN                 NaN      8370  False  False
# 1                 6.0                14.0     15200  False  False
# ...

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 0       P00069042       0  NaN          10             A
# 1       P00248942       0  NaN          10             A
# 2       P00087842       0  NaN          10             A
# 3       P00085442       0  NaN          10             A
# 4       P00285442       1  NaN          16             C
# ...           ...     ...  ...         ...           ...
# 550063  P00372445       1  NaN          13             B
# 550064  P00375436       0  NaN           1             C
# 550065  P00375436       0  NaN          15             B
# 550066  P00375436       0  NaN           1             C
# 550067  P00371644       0  NaN           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df.drop('City_Category',axis=1,inplace=True)

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       0  NaN          10                          2
# 1       P00248942       0  NaN          10                          2
# 2       P00087842       0  NaN          10                          2
# 3       P00085442       0  NaN          10                          2
# 4       P00285442       1  NaN          16                         4+
# ...           ...     ...  ...         ...                        ...
# 550063  P00372445       1  NaN          13                          1
# 550064  P00375436       0  NaN           1                          3
# 550065  P00375436       0  NaN          15                         4+
# 550066  P00375436       0  NaN           1                          2
# 550067  P00371644       0  NaN           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                           550068
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# B                             550068
# C                             550068
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  550068 non-null  object
#  1   Gender                      550068 non-null  int64
#  2   Age                         0 non-null       float64
#  3   Occupation                  550068 non-null  int64
#  4   Stay_In_Current_City_Years  550068 non-null  object
#  5   Marital_Status              550068 non-null  int64
#  6   Product_Category_1          550068 non-null  int64
#  7   Product_Category_2          376430 non-null  float64
#  8   Product_Category_3          166821 non-null  float64
#  9   Purchase                    550068 non-null  int64
#  10  B                           0 non-null       float64
#  11  C                           0 non-null       float64
# dtypes: float64(5), int64(5), object(2)
# ...

# %%
df.shape
# Out:
# (550068, 12)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19], dtype=int64)

# %%
df['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df['Product_Category_2'].value_counts()
# Out:
# Product_Category_2
# 8.0     64088
# 14.0    55108
# 2.0     49217
# 16.0    43255
# 15.0    37855
# 5.0     26235
# 4.0     25677
# 6.0     16466
# 11.0    14134
# 17.0    13320
# 13.0    10531
# 9.0      5693
# 12.0     5528
# 10.0     3043
# 3.0      2884
# 18.0     2770
# 7.0       626
# Name: count, dtype: int64

# %%
df['Product_Category_2'].mode()[0]
# Out:
# 8.0

# %%
df['Product_Category_2'] = df['Product_Category_2'].fillna(df['Product_Category_2'])[0]

# %%
df['Product_Category_2'].isnull().sum()
# Out:
# 0

# %%
df['Product_Category_1'] = df['Product_Category_1'].fillna(df['Product_Category_1'])[0]

# %%
df['Product_Category_1'].isnull().sum()
# Out:
# 0

# %%
df['Product_Category_3'].isnull().sum()
# Out:
# 550068

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       0  NaN          10                          2
# 1       P00248942       0  NaN          10                          2
# 2       P00087842       0  NaN          10                          2
# 3       P00085442       0  NaN          10                          2
# 4       P00285442       1  NaN          16                         4+
# ...           ...     ...  ...         ...                        ...
# 550063  P00372445       1  NaN          13                          1
# 550064  P00375436       0  NaN           1                          3
# 550065  P00375436       0  NaN          15                         4+
# 550066  P00375436       0  NaN           1                          2
# 550067  P00371644       0  NaN           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df.drop('Product_Category_3',axis=1,inplace=True)

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       0  NaN          10                          2
# 1       P00248942       0  NaN          10                          2
# 2       P00087842       0  NaN          10                          2
# 3       P00085442       0  NaN          10                          2
# 4       P00285442       1  NaN          16                         4+
# ...           ...     ...  ...         ...                        ...
# 550063  P00372445       1  NaN          13                          1
# 550064  P00375436       0  NaN           1                          3
# 550065  P00375436       0  NaN          15                         4+
# 550066  P00375436       0  NaN           1                          2
# 550067  P00371644       0  NaN           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  Purchase   B  \
# ...

# %%
df.shape
# Out:
# (550068, 11)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
Stay_In_Current_City_Years=df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].astype(str).str.replace(r'\+', '', regex=True)

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042       0  NaN          10                          2
# 1  P00248942       0  NaN          10                          2
# 2  P00087842       0  NaN          10                          2
# 3  P00085442       0  NaN          10                          2
# 4  P00285442       1  NaN          16                          4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Purchase   B   C
# 0               0                   3                 8.0      8370 NaN NaN
# 1               0                   3                 8.0     15200 NaN NaN
# 2               0                   3                 8.0      1422 NaN NaN
# 3               0                   3                 8.0      1057 NaN NaN
# 4               0                   3                 8.0      7969 NaN NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  550068 non-null  object
#  1   Gender                      550068 non-null  int64
#  2   Age                         0 non-null       float64
#  3   Occupation                  550068 non-null  int64
#  4   Stay_In_Current_City_Years  550068 non-null  object
#  5   Marital_Status              550068 non-null  int64
#  6   Product_Category_1          550068 non-null  int64
#  7   Product_Category_2          550068 non-null  float64
#  8   Purchase                    550068 non-null  int64
#  9   B                           0 non-null       float64
#  10  C                           0 non-null       float64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 46.2+ MB

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].astype(int)

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0       P00069042       0  NaN          10                           2
# 1       P00248942       0  NaN          10                           2
# 2       P00087842       0  NaN          10                           2
# 3       P00085442       0  NaN          10                           2
# 4       P00285442       1  NaN          16                           4
# ...           ...     ...  ...         ...                         ...
# 550063  P00372445       1  NaN          13                           1
# 550064  P00375436       0  NaN           1                           3
# 550065  P00375436       0  NaN          15                           4
# 550066  P00375436       0  NaN           1                           2
# 550067  P00371644       0  NaN           0                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2  Purchase   B  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  550068 non-null  object
#  1   Gender                      550068 non-null  int64
#  2   Age                         0 non-null       float64
#  3   Occupation                  550068 non-null  int64
#  4   Stay_In_Current_City_Years  550068 non-null  int32
#  5   Marital_Status              550068 non-null  int64
#  6   Product_Category_1          550068 non-null  int64
#  7   Product_Category_2          550068 non-null  float64
#  8   Purchase                    550068 non-null  int64
#  9   B                           0 non-null       float64
#  10  C                           0 non-null       float64
# dtypes: float64(4), int32(1), int64(5), object(1)
# memory usage: 44.1+ MB

# %%
sns.barplot('Age','Purchase',hue='Gender',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[291], line 1
# ----> 1 sns.barplot('Age','Purchase',hue='Gender',data=df)
#
# TypeError: barplot() got multiple values for argument 'data'

# %%
print(df[['Age', 'Purchase', 'Gender']].isnull().sum())  # Ensure no missing values
# Out:
# Age         0
# Purchase    0
# Gender      0
# dtype: int64

# %%
sns.pairplot('Age','Purchase',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[316], line 1
# ----> 1 sns.pairplot('Age','Purchase',data=df)
#
# TypeError: pairplot() got multiple values for argument 'data'
